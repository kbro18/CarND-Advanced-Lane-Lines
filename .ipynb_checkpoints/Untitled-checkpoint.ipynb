# %%
import numpy as np
import cv2
import glob
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load calibration images.
calibrationImages = list(map(lambda imageFileName: (imageFileName, cv2.imread(imageFileName)), glob.glob('./camera_cal/c*.jpg')))

# %%
def showImages(images, cols = 4, rows = 5, figsize=(15,10)):
    """
    Display `images` on a [`cols`, `rows`] subplot grid.
    """
    imgLength = len(images)
    fig, axes = plt.subplots(rows, cols, figsize=figsize)
    indexes = range(cols * rows)
    for ax, index in zip(axes.flat, indexes):
        if index < imgLength:
            imagePathName, image = images[index]
            ax.imshow(image)
            ax.set_title(imagePathName)
        
showImages(calibrationImages, 4, 5, (15, 13))

# %%
objpoints = []
imgpoints = []
outimages = []
originalImages = []

objp = np.zeros((6*9,3), np.float32) 
objp[:,:2] = np.mgrid[0:9,0:6].T.reshape(-1,2) # x and y cordinates.

for imageAndFile in calibrationImages:
    fileName, image = imageAndFile
    print(fileName)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    ret, corners = cv2.findChessboardCorners(gray, (9,6), None)

    if ret == True:
        imgpoints.append(corners)
        objpoints.append(objp)

        img_points = cv2.drawChessboardCorners(image.copy(), (9,6), corners, ret)
        outimages.append(img_points)
        originalImages.append(image)

print('Image with corner found: {}'.format(len(outimages)))
# Out:
# ./camera_cal/calibration5.jpg
# ./camera_cal/calibration4.jpg
# ./camera_cal/calibration6.jpg
# ./camera_cal/calibration7.jpg
# ./camera_cal/calibration3.jpg
# ./camera_cal/calibration2.jpg
# ./camera_cal/calibration1.jpg
# ./camera_cal/calibration20.jpg
# ./camera_cal/calibration19.jpg
# ./camera_cal/calibration18.jpg
# ./camera_cal/calibration15.jpg
# ./camera_cal/calibration14.jpg
# ./camera_cal/calibration16.jpg
# ./camera_cal/calibration17.jpg
# ./camera_cal/calibration13.jpg
# ./camera_cal/calibration12.jpg
# ./camera_cal/calibration10.jpg
# ./camera_cal/calibration11.jpg
# ./camera_cal/calibration9.jpg
# ./camera_cal/calibration8.jpg
# Image with corner found: 17

# %%
index = 10
original = originalImages[index]
chessPoints = outimages[index]
fig, axes = plt.subplots(ncols=2, figsize=(20, 10))
axes[0].imshow(original)
axes[0].set_title('Original')
axes[1].imshow(chessPoints)
axes[1].set_title('With points')

# %%
ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, original.shape[0:2], None, None)
print("ret:", ret)
# Out:
# ret: 1.0298153371058991

# %%
undist = cv2.undistort(original, mtx, dist, None, mtx)

# %%
fig, axes = plt.subplots(ncols=2, figsize=(20, 10))
axes[0].imshow(original)
axes[0].set_title('Original')
axes[1].imshow(undist)
axes[1].set_title('Undistort')

# %%
import pickle
pickle.dump( { 'mtx': mtx, 'dist': dist }, open('./pickled_data/camera_calibration.p', 'wb'))

# %%
for imageAndFile in calibrationImages:
    fileName, image = imageAndFile
    print(fileName, fileName[13:])
    cv2.imwrite("./camera_cal_output/" + fileName[11:] , cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    #undist = cv2.undistort(image, mtx, dist, None, mtx)
    #cv2.imwrite("./camera_cal_output/other/undistorted_" + fileName[11:] , cv2.cvtColor(undist, cv2.COLOR_BGR2RGB))
# Out:
# ./camera_cal/calibration5.jpg calibration5.jpg
# ./camera_cal/calibration4.jpg calibration4.jpg
# ./camera_cal/calibration6.jpg calibration6.jpg
# ./camera_cal/calibration7.jpg calibration7.jpg
# ./camera_cal/calibration3.jpg calibration3.jpg
# ./camera_cal/calibration2.jpg calibration2.jpg
# ./camera_cal/calibration1.jpg calibration1.jpg
# ./camera_cal/calibration20.jpg calibration20.jpg
# ./camera_cal/calibration19.jpg calibration19.jpg
# ./camera_cal/calibration18.jpg calibration18.jpg
# ./camera_cal/calibration15.jpg calibration15.jpg
# ./camera_cal/calibration14.jpg calibration14.jpg
# ./camera_cal/calibration16.jpg calibration16.jpg
# ./camera_cal/calibration17.jpg calibration17.jpg
# ./camera_cal/calibration13.jpg calibration13.jpg
# ./camera_cal/calibration12.jpg calibration12.jpg
# ./camera_cal/calibration10.jpg calibration10.jpg
# ./camera_cal/calibration11.jpg calibration11.jpg
# ./camera_cal/calibration9.jpg calibration9.jpg
# ./camera_cal/calibration8.jpg calibration8.jpg
